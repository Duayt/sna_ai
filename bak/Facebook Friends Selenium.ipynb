# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# create a new Firefox session
driver = webdriver.Chrome()
driver.implicitly_wait(30)
driver.maximize_window()

# %%
driver.get("https://facebook.com/"+username+"/friends")

# %%
from bs4 import BeautifulSoup 
import json
import time

def find_all_friends(username):
    driver.get("https://facebook.com/"+username+"/friends")
    l = 0
    last_l = -1
    friend_list = []
    while last_l != l:
        friends = driver.find_elements_by_class_name("_5qo4")
        print('Interpreting Data')
        for friend in friends[l:]:
            soup = BeautifulSoup(friend.get_attribute('innerHTML'), 'html.parser')
            divs = soup.find_all('div', {'class': 'fsl fwb fcb'})
            for div in divs:
                name=div.get_text()
                # print(name)
                for a in div.find_all('a', href=True) :
                    link=a['href'][:a['href'].find('?')]
                    try:
                        user_id=json.loads(a['data-gt'])['engagement']['eng_tid']
                    except:
                        user_id='xxxx'
                if user_id == 'xxxx':
                    break
                friend_list.append((name,link,user_id))
        print('Scrolling Down')
        for i in range(20):
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(0.5)
        last_l = l
        l = len(friends)
        print(len(friend_list), 'friends were collected.')
    return friend_list

# %%
import random
import os.path

output_filename = 'friend_list.csv'
def get_name(name,url,uid):
    if 'profile.php' in url:
        user_url = name+'|'+uid
    else:
        user_url = url[url.find('/',10)+1:]
    return user_url

if not os.path.exists(output_filename):
    source_user = 'prophecyx'
else:
    file = open(output_filename,'r')
    f_list = file.readlines()
    first_user_list = [line.split(',')[0] for line in f_list]
    source_user = random.choice(f_list).split(',')[1].strip()
    while source_user in first_user_list:
        source_user = random.choice(f_list).split(',')[1].strip()
    file.close()    

while True:
    friend_list = find_all_friends(source_user)
    new_friend_list = [(source_user,get_name(name,url,u_id)) for name,url,u_id in friend_list]
    file = open(output_filename,'a')
    for c in new_friend_list:
        file.write(c[0]+','+c[1])
        file.write('\n')
    file.close()
    file = open(output_filename,'r')
    f_list = file.readlines()
    first_user_list = [line.split(',')[0] for line in f_list]
    source_user = random.choice(f_list).split(',')[1].strip()
    while source_user in first_user_list:
        source_user = random.choice(f_list).split(',')[1].strip()
    file.close()
# Out:
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 139 friends were collected.
# Interpreting Data
# Scrolling Down
# 355 friends were collected.
# Interpreting Data
# Scrolling Down
# 569 friends were collected.
# Interpreting Data
# Scrolling Down
# 815 friends were collected.
# Interpreting Data
# Scrolling Down
# 996 friends were collected.
# Interpreting Data
# Scrolling Down
# 996 friends were collected.
# Interpreting Data
# Scrolling Down
# 996 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 260 friends were collected.
# Interpreting Data
# Scrolling Down
# 480 friends were collected.
# Interpreting Data
# Scrolling Down
# 487 friends were collected.
# Interpreting Data
# Scrolling Down
# 487 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 200 friends were collected.
# Interpreting Data
# Scrolling Down
# 420 friends were collected.
# Interpreting Data
# Scrolling Down
# 600 friends were collected.
# Interpreting Data
# Scrolling Down
# 820 friends were collected.
# Interpreting Data
# Scrolling Down
# 1000 friends were collected.
# Interpreting Data
# Scrolling Down
# 1160 friends were collected.
# Interpreting Data
# Scrolling Down
# 1360 friends were collected.
# Interpreting Data
# Scrolling Down
# 1560 friends were collected.
# Interpreting Data
# Scrolling Down
# 1740 friends were collected.
# Interpreting Data
# Scrolling Down
# 1940 friends were collected.
# Interpreting Data
# Scrolling Down
# 2120 friends were collected.
# Interpreting Data
# Scrolling Down
# 2300 friends were collected.
# Interpreting Data
# Scrolling Down
# 2480 friends were collected.
# Interpreting Data
# Scrolling Down
# 2680 friends were collected.
# Interpreting Data
# Scrolling Down
# 2760 friends were collected.
# Interpreting Data
# Scrolling Down
# 2960 friends were collected.
# Interpreting Data
# Scrolling Down
# 3180 friends were collected.
# Interpreting Data
# Scrolling Down
# 3360 friends were collected.
# Interpreting Data
# Scrolling Down
# 3540 friends were collected.
# Interpreting Data
# Scrolling Down
# 3720 friends were collected.
# Interpreting Data
# Scrolling Down
# 3900 friends were collected.
# Interpreting Data
# Scrolling Down
# 4076 friends were collected.
# Interpreting Data
# Scrolling Down
# 4076 friends were collected.
# Interpreting Data
# Scrolling Down
# 4076 friends were collected.
# Interpreting Data
# Scrolling Down
# 100 friends were collected.
# Interpreting Data
# Scrolling Down
# 500 friends were collected.
# Interpreting Data
# Scrolling Down
# 500 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 92 friends were collected.
# Interpreting Data
# Scrolling Down
# 92 friends were collected.
# Interpreting Data
# Scrolling Down
# 100 friends were collected.
# Interpreting Data
# Scrolling Down
# 382 friends were collected.
# Interpreting Data
# Scrolling Down
# 382 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 240 friends were collected.
# Interpreting Data
# Scrolling Down
# 440 friends were collected.
# Interpreting Data
# Scrolling Down
# 640 friends were collected.
# Interpreting Data
# Scrolling Down
# 860 friends were collected.
# Interpreting Data
# Scrolling Down
# 1060 friends were collected.
# Interpreting Data
# Scrolling Down
# 1260 friends were collected.
# Interpreting Data
# Scrolling Down
# 1440 friends were collected.
# Interpreting Data
# Scrolling Down
# 1660 friends were collected.
# Interpreting Data
# Scrolling Down
# 1695 friends were collected.
# Interpreting Data
# Scrolling Down
# 1695 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 320 friends were collected.
# Interpreting Data
# Scrolling Down
# 560 friends were collected.
# Interpreting Data
# Scrolling Down
# 617 friends were collected.
# Interpreting Data
# Scrolling Down
# 617 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 27 friends were collected.
# Interpreting Data
# Scrolling Down
# 27 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 300 friends were collected.
# Interpreting Data
# Scrolling Down
# 437 friends were collected.
# Interpreting Data
# Scrolling Down
# 437 friends were collected.
# Interpreting Data
# Scrolling Down
# 437 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 420 friends were collected.
# Interpreting Data
# Scrolling Down
# 620 friends were collected.
# Interpreting Data
# Scrolling Down
# 800 friends were collected.
# Interpreting Data
# Scrolling Down
# 1020 friends were collected.
# Interpreting Data
# Scrolling Down
# 1200 friends were collected.
# Interpreting Data
# Scrolling Down
# 1400 friends were collected.
# Interpreting Data
# Scrolling Down
# 1600 friends were collected.
# Interpreting Data
# Scrolling Down
# 1641 friends were collected.
# Interpreting Data
# Scrolling Down
# 1641 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 420 friends were collected.
# Interpreting Data
# Scrolling Down
# 580 friends were collected.
# Interpreting Data
# Scrolling Down
# 760 friends were collected.
# Interpreting Data
# Scrolling Down
# 940 friends were collected.
# Interpreting Data
# Scrolling Down
# 1120 friends were collected.
# Interpreting Data
# Scrolling Down
# 1320 friends were collected.
# Interpreting Data
# Scrolling Down
# 1520 friends were collected.
# Interpreting Data
# Scrolling Down
# 1740 friends were collected.
# Interpreting Data
# Scrolling Down
# 1940 friends were collected.
# Interpreting Data
# Scrolling Down
# 2120 friends were collected.
# Interpreting Data
# Scrolling Down
# 2340 friends were collected.
# Interpreting Data
# Scrolling Down
# 2520 friends were collected.
# Interpreting Data
# Scrolling Down
# 2660 friends were collected.
# Interpreting Data
# Scrolling Down
# 2860 friends were collected.
# Interpreting Data
# Scrolling Down
# 3060 friends were collected.
# Interpreting Data
# Scrolling Down
# 3260 friends were collected.
# Interpreting Data
# Scrolling Down
# 3420 friends were collected.
# Interpreting Data
# Scrolling Down
# 3617 friends were collected.
# Interpreting Data
# Scrolling Down
# 3617 friends were collected.
# Interpreting Data
# Scrolling Down
# 3617 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 380 friends were collected.
# Interpreting Data
# Scrolling Down
# 500 friends were collected.
# Interpreting Data
# Scrolling Down
# 680 friends were collected.
# Interpreting Data
# Scrolling Down
# 900 friends were collected.
# Interpreting Data
# Scrolling Down
# 1020 friends were collected.
# Interpreting Data
# Scrolling Down
# 1220 friends were collected.
# Interpreting Data
# Scrolling Down
# 1400 friends were collected.
# Interpreting Data
# Scrolling Down
# 1600 friends were collected.
# Interpreting Data
# Scrolling Down
# 1800 friends were collected.
# Interpreting Data
# Scrolling Down
# 2000 friends were collected.
# Interpreting Data
# Scrolling Down
# 2200 friends were collected.
# Interpreting Data
# Scrolling Down
# 2380 friends were collected.
# Interpreting Data
# Scrolling Down
# 2600 friends were collected.
# Interpreting Data
# Scrolling Down
# 2800 friends were collected.
# Interpreting Data
# Scrolling Down
# 2980 friends were collected.
# Interpreting Data
# Scrolling Down
# 3180 friends were collected.
# Interpreting Data
# Scrolling Down
# 3360 friends were collected.
# Interpreting Data
# Scrolling Down
# 3560 friends were collected.
# Interpreting Data
# Scrolling Down
# 3740 friends were collected.
# Interpreting Data
# Scrolling Down
# 3900 friends were collected.
# Interpreting Data
# Scrolling Down
# 4060 friends were collected.
# Interpreting Data
# Scrolling Down
# 4240 friends were collected.
# Interpreting Data
# Scrolling Down
# 4400 friends were collected.
# Interpreting Data
# Scrolling Down
# 4446 friends were collected.
# Interpreting Data
# Scrolling Down
# 4446 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 240 friends were collected.
# Interpreting Data
# Scrolling Down
# 440 friends were collected.
# Interpreting Data
# Scrolling Down
# 640 friends were collected.
# Interpreting Data
# Scrolling Down
# 749 friends were collected.
# Interpreting Data
# Scrolling Down
# 749 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 400 friends were collected.
# Interpreting Data
# Scrolling Down
# 620 friends were collected.
# Interpreting Data
# Scrolling Down
# 820 friends were collected.
# Interpreting Data
# Scrolling Down
# 1000 friends were collected.
# Interpreting Data
# Scrolling Down
# 1220 friends were collected.
# Interpreting Data
# Scrolling Down
# 1420 friends were collected.
# Interpreting Data
# Scrolling Down
# 1580 friends were collected.
# Interpreting Data
# Scrolling Down
# 1800 friends were collected.
# Interpreting Data
# Scrolling Down
# 1891 friends were collected.
# Interpreting Data
# Scrolling Down
# 1891 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 400 friends were collected.
# Interpreting Data
# Scrolling Down
# 600 friends were collected.
# Interpreting Data
# Scrolling Down
# 780 friends were collected.
# Interpreting Data
# Scrolling Down
# 980 friends were collected.
# Interpreting Data
# Scrolling Down
# 1180 friends were collected.
# Interpreting Data
# Scrolling Down
# 1360 friends were collected.
# Interpreting Data
# Scrolling Down
# 1401 friends were collected.
# Interpreting Data
# Scrolling Down
# 1401 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 420 friends were collected.
# Interpreting Data
# Scrolling Down
# 620 friends were collected.
# Interpreting Data
# Scrolling Down
# 820 friends were collected.
# Interpreting Data
# Scrolling Down
# 1000 friends were collected.
# Interpreting Data
# Scrolling Down
# 1200 friends were collected.
# Interpreting Data
# Scrolling Down
# 1400 friends were collected.
# Interpreting Data
# Scrolling Down
# 1476 friends were collected.
# Interpreting Data
# Scrolling Down
# 1476 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 140 friends were collected.
# Interpreting Data
# Scrolling Down
# 311 friends were collected.
# Interpreting Data
# Scrolling Down
# 311 friends were collected.
# Interpreting Data
# Scrolling Down
# 311 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 440 friends were collected.
# Interpreting Data
# Scrolling Down
# 640 friends were collected.
# Interpreting Data
# Scrolling Down
# 860 friends were collected.
# Interpreting Data
# Scrolling Down
# 1060 friends were collected.
# Interpreting Data
# Scrolling Down
# 1085 friends were collected.
# Interpreting Data
# Scrolling Down
# 1085 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 240 friends were collected.
# Interpreting Data
# Scrolling Down
# 240 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 80 friends were collected.
# Interpreting Data
# Scrolling Down
# 160 friends were collected.
# Interpreting Data
# Scrolling Down
# 160 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 80 friends were collected.
# Interpreting Data
# Scrolling Down
# 160 friends were collected.
# Interpreting Data
# Scrolling Down
# 240 friends were collected.
# Interpreting Data
# Scrolling Down
# 320 friends were collected.
# Interpreting Data
# Scrolling Down
# 400 friends were collected.
# Interpreting Data
# Scrolling Down
# 460 friends were collected.
# Interpreting Data
# Scrolling Down
# 540 friends were collected.
# Interpreting Data
# Scrolling Down
# 640 friends were collected.
# Interpreting Data
# Scrolling Down
# 640 friends were collected.
# Interpreting Data
# Scrolling Down
# 100 friends were collected.
# Interpreting Data
# Scrolling Down
# 100 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 80 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 400 friends were collected.
# Interpreting Data
# Scrolling Down
# 600 friends were collected.
# Interpreting Data
# Scrolling Down
# 800 friends were collected.
# Interpreting Data
# Scrolling Down
# 980 friends were collected.
# Interpreting Data
# Scrolling Down
# 1140 friends were collected.
# Interpreting Data
# Scrolling Down
# 1360 friends were collected.
# Interpreting Data
# Scrolling Down
# 1560 friends were collected.
# Interpreting Data
# Scrolling Down
# 1740 friends were collected.
# Interpreting Data
# Scrolling Down
# 1940 friends were collected.
# Interpreting Data
# Scrolling Down
# 2160 friends were collected.
# Interpreting Data
# Scrolling Down
# 2360 friends were collected.
# Interpreting Data
# Scrolling Down
# 2500 friends were collected.
# Interpreting Data
# Scrolling Down
# 2700 friends were collected.
# Interpreting Data
# Scrolling Down
# 2900 friends were collected.
# Interpreting Data
# Scrolling Down
# 3100 friends were collected.
# Interpreting Data
# Scrolling Down
# 3280 friends were collected.
# Interpreting Data
# Scrolling Down
# 3460 friends were collected.
# Interpreting Data
# Scrolling Down
# 3640 friends were collected.
# Interpreting Data
# Scrolling Down
# 3840 friends were collected.
# Interpreting Data
# Scrolling Down
# 4040 friends were collected.
# Interpreting Data
# Scrolling Down
# 4220 friends were collected.
# Interpreting Data
# Scrolling Down
# 4380 friends were collected.
# Interpreting Data
# Scrolling Down
# 4560 friends were collected.
# Interpreting Data
# Scrolling Down
# 4606 friends were collected.
# Interpreting Data
# Scrolling Down
# 4606 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 100 friends were collected.
# Interpreting Data
# Scrolling Down
# 280 friends were collected.
# Interpreting Data
# Scrolling Down
# 480 friends were collected.
# Interpreting Data
# Scrolling Down
# 700 friends were collected.
# Interpreting Data
# Scrolling Down
# 880 friends were collected.
# Interpreting Data
# Scrolling Down
# 1060 friends were collected.
# Interpreting Data
# Scrolling Down
# 1280 friends were collected.
# Interpreting Data
# Scrolling Down
# 1480 friends were collected.
# Interpreting Data
# Scrolling Down
# 1620 friends were collected.
# Interpreting Data
# Scrolling Down
# 1820 friends were collected.
# Interpreting Data
# Scrolling Down
# 2013 friends were collected.
# Interpreting Data
# Scrolling Down
# 2013 friends were collected.
# Interpreting Data
# Scrolling Down
# 2013 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 0 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 200 friends were collected.
# Interpreting Data
# Scrolling Down
# 400 friends were collected.
# Interpreting Data
# Scrolling Down
# 560 friends were collected.
# Interpreting Data
# Scrolling Down
# 720 friends were collected.
# Interpreting Data
# Scrolling Down
# 880 friends were collected.
# Interpreting Data
# Scrolling Down
# 1040 friends were collected.
# Interpreting Data
# Scrolling Down
# 1240 friends were collected.
# Interpreting Data
# Scrolling Down
# 1440 friends were collected.
# Interpreting Data
# Scrolling Down
# 1620 friends were collected.
# Interpreting Data
# Scrolling Down
# 1840 friends were collected.
# Interpreting Data
# Scrolling Down
# 2040 friends were collected.
# Interpreting Data
# Scrolling Down
# 2220 friends were collected.
# Interpreting Data
# Scrolling Down
# 2400 friends were collected.
# Interpreting Data
# Scrolling Down
# 2580 friends were collected.
# Interpreting Data
# Scrolling Down
# 2760 friends were collected.
# Interpreting Data
# Scrolling Down
# 2960 friends were collected.
# Interpreting Data
# Scrolling Down
# 3140 friends were collected.
# Interpreting Data
# Scrolling Down
# 3340 friends were collected.
# Interpreting Data
# Scrolling Down
# 3500 friends were collected.
# Interpreting Data
# Scrolling Down
# 3680 friends were collected.
# Interpreting Data
# Scrolling Down
# 3860 friends were collected.
# Interpreting Data
# Scrolling Down
# 4060 friends were collected.
# Interpreting Data
# Scrolling Down
# 4152 friends were collected.
# Interpreting Data
# Scrolling Down
# 4152 friends were collected.
# Interpreting Data
# Scrolling Down
# 4152 friends were collected.
# Interpreting Data
# Scrolling Down
# 1 friends were collected.
# Interpreting Data
# Scrolling Down
# 1 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 180 friends were collected.
# Interpreting Data
# Scrolling Down
# 400 friends were collected.
# Interpreting Data
# Scrolling Down
# 600 friends were collected.
# Interpreting Data
# Scrolling Down
# 800 friends were collected.
# Interpreting Data
# Scrolling Down
# 1000 friends were collected.
# Interpreting Data
# Scrolling Down
# 1180 friends were collected.
# Interpreting Data
# Scrolling Down
# 1380 friends were collected.
# Interpreting Data
# Scrolling Down
# 1513 friends were collected.
# Interpreting Data
# Scrolling Down
# 1513 friends were collected.
# Interpreting Data
# Scrolling Down
# 1513 friends were collected.
# Interpreting Data
# Scrolling Down
# 20 friends were collected.
# Interpreting Data
# Scrolling Down
# 220 friends were collected.
# Interpreting Data
# Scrolling Down
# 400 friends were collected.
# Interpreting Data
# Scrolling Down
# 580 friends were collected.
# Interpreting Data
# Scrolling Down
